# %% [markdown]
# # Variablen und Datentypen
#
# ## Lernziele
#
# - Variablen
# - Datentypen

# %% [markdown]
# ## Variablen
#
# Jeder Python-Interpreter kann als Taschenrechner benutzt werden:

# %%
3 + 5 * 4

# %% [markdown]
# Das ist toll, aber nicht sehr interessant. Um mit Daten etwas wirklich Sinnvolles anfangen zu können, müssen wir ihren Wert einer Variablen zuweisen. In Python können wir einer Variablen einen Wert zuweisen, indem wir das Gleichheitszeichen (=) verwenden.
#
# Im nachfolgenden Codeschnipsel ordnet Python der Variablen _märchen_ die Zahl 86 zu und der Variablen _name_ den Wert 'Grimm' in einfachen Anführungszeichen. Namen, Wörter oder Sätze, die in einer Variablen gespeichert werden, müssen in einfachen oder doppelten Anführungszeichen geschrieben werden. Die Erläuterung dazu, wieso das so ist, erfolgt zu einem späteren Zeitpunkt in dieser Einheit. Bitte führe die nachfolgende Zelle aus:

# %%
märchen = 86
name = 'Grimm'

# %% [markdown]
# Jetzt haben wir eine Art Speicher-Container, sprich die Variable _märchen_, und in der den Wert 86 gespeichert und wir haben in der Variablen _name_ den Wert 'Grimm' gespeichert. Im Grunde ist eine Variable also eine Art Speichercontainer für einen Wert. Und wir vergeben für diesen Container einen Namen.
#
# Geben wir in einer Code-Zelle den Variablennamen ein und führen diese aus, so erscheint der Wert in der Ausgabe.

# %%
märchen

# %% [markdown]
# Wenn alles geklappt hat, sollte hier `86` erscheinen.
# *Hinweis:* Bei einer Fehlermeldung muss bedacht werden, dass auch die Zelle vorher, wo die Werte in Variablen gespeichert werden, ausgeführt sein muss, bevor die obere Zelle mit der Ausgabe funktioniert.

# %%
name

# %% [markdown]
# Und wenn hier auch alles geklappt hat, sollte hier `'Grimm'` stehen.

# %% [markdown]
# ---
#
# ### Hinweise
#
# Variablennamen...
#
# - können nicht mit einer Zahl starten.
# - können keine Leerzeichen enthalten.
# - können Unterstriche enthalten (typischerweise, um separate Wörter zu verbinden).
# - sind case sensitive, beachten also die Groß- und Kleinschreibung. Das heißt: "name" und "Name" sind zwei unterschiedliche Variablen.
#
# Für unser Fallbeispiel heißt das:
# - _märchen_ ist ein gültiger Variablenname.
# - _0märchen_ ist dagegen kein gültiger Variablenname.
# - _märchen_ and _Märchen_ wären zwei verschiedene Variablen.
#
#
# ---
#
#
# -> Immer, wenn wir im Folgenden _märchen_ oder _name_ verwenden, wird Python den Wert nutzen, den wir der Variablen zugewiesen haben.

# %% [markdown]
# ## Datentypen
#
# Python kennt verschiedene Arten von Datentypen. Die drei gängigsten sind:
# - Integer (Ganze Zahlen, abgekürzt: int)
# - Floats (Kommazahlen, abgekürzt: float)
# - Strings (Zeichenketten / Wörter, abgekürzt str). Insbesondere mit Strings werden wir nachfolgend verstärkt arbeiten.
#
# In dem vorangegangenen Beispiel hat die Variable *märchen* den Datentyp Integer und die Variable *name* den Datentyp String.

# %% [markdown]
# ### Eingebaute Python-Funktionen
#
# Bevor wir uns intensiver mit Strings bzw. Zeichenketten beschäftigen, sollten wir noch einige grundlegende Informationen zu Integer und Floats anhand von eingebauten Python-Funktionen kennenlernen.
#
# Sobald wir Daten mit Variablennamen gespeichert haben, können wir sie in Berechnungen verwenden.

# %%
märchen = 86
märchen = 86 + 4

# %% [markdown]
# Um Aufgaben mit Daten und Variablen in Python auszuführen, stellt uns die Sprache mehrere eingebaute Funktionen zur Verfügung. Um Informationen auf dem Bildschirm anzuzeigen, benutzen wir die von Python zur Verfügung gestellte Funktion "print()":
#
# *Hinweis:* Von Python bereitgestellte Funktionen/Funktionsnamen sind IMMER auf Englisch. Und print() bedeutet nichts anderes als "ausgeben".

# %%
print(märchen)

# %% [markdown]
# Alles geklappt? Dann steht als Ausgabe oben nun: `90`
#
# Wir sehen also, dass *märchen* nun einen zugewiesenen Wert von 90 hat. Denn: durch unsere vorige Zuweisung (märchen = 86 + 4) erhält die Variable _märchen_ den zugewiesenen Wert 90. Das ist eine ganze Zahl und somit ein Integer.
#
# Obwohl floats Gleitkommazahlen sind, werden sie in Python durch einen Punkt getrennt. Das probieren wir direkt aus: Wir weisen durch Ausführen des folgenden Codes der Variablen _float_ einen Wert von 10,4 zu:

# %%
kommazahl = 10.4

# %% [markdown]
# **Achtung:** Bei Floatwerten, also Kommazahlen, wird der Wert nicht mit einem Komma getrennt, sondern mit einem Punkt!
#
# Wenn wir eine ganze Zahl, also einen Integerwert, mit einem Floatwert addieren, erhalten wir dadurch wieder einen Floatwert, den wir in einer neuen Variablen namens _berechnung_float_ speichern:

# %%
berechnung_float = märchen + kommazahl
print(berechnung_float)

# %% [markdown]
# Wenn alles geklappt hat, steht oben nun: `100.4`
#
# Aber: So wie integers und floats können wir auch Strings miteinander verbinden. Wir nehmen einen neuen String (eine Zeichenkette) und 'addieren' den Variablennamen dazu:

# %%
name = 'Grimm'
fullname = 'Gebrüder ' + name
print(fullname)

# %% [markdown]
# Das Ergebnis sollte Gebrüder Grimm sein.
#
# *Hinweis: Das Leerzeichen hinter 'Gebrüder' muss in die einfachen Anführungszeichen gesetzt werden, da sonst beide Strings ohne Leerzeichen direkt miteinander verbunden werden würden.*
#
# Für den Fall, dass man mit Variablen arbeitet, bei denen man sich unsicher ist, welcher Datentyp sich hinter dem Wert verbirgt, gibt es in Python eine eingebaute Funktion, die uns den Datentyp ausgibt: type()

# %%
print(type(berechnung_float),
      type(märchen),
      type(fullname),
      type(print))

# %% [markdown]
# Erwarteter Output: `<class 'float'> <class 'int'> <class 'str'> <class 'builtin_function_or_method'>`
#
# - _berechnung_float_ ist ein Beispiel für eine Gleitkommazahl oder float. Dies sind Kommazahlen.
# - Der Wert der Variablen *märchen* ist 90, also eine ganze Zahl und somit ein integer (int).
# - Die Variable *fullname* bezieht sich auf die Zeichenkette / den String (str) von 'Gebrüder Grimm'.
# - Die eingebaute Python-Funktion print() ist ebenfalls ein Objekt mit einem Typ, in diesem Fall ist es eine builtin_function_or_method.
#
# Wenn wir eine Funktion verwenden, also einen "Funktionsaufruf" durchführen wollen, setzen wir den Namen der Funktion in Klammern. Die Klammern sind wichtig: Wenn sie weggelassen werden, wird die Funktion nicht richtig ausgeführt!
#
# Wir können mit einem einzigen Aufruf von print() aber auch mehrere Dinge auf einmal anzeigen:

# %%
print('Die', fullname, 'haben', märchen, 'Märchen geschrieben.')

# %% [markdown]
# Und hat es geklappt? Dann sollte oben stehen: `Die Gebrüder Grimm haben 90 Märchen geschrieben.`
#
# Um den Wert der Variablen *märchen* zu ändern, müssen wir *märchen* mit dem Gleichheitszeichen (=) einen neuen Wert zuweisen:

# %%
märchen = 200
print(märchen)

# %% [markdown]
# ---
#
# ##### Tipp:
# Eine Variable ist wie eine Klebenotiz auf dem ein Name steht: Wenn man einer Variablen einen Wert zuweist, ist das so, als würde man den Klebezettel auf einen Wert kleben.
#
# Anhand dieser Analogie können wir untersuchen, wie die Zuweisung eines Wertes an eine Variable die Werte anderer, scheinbar verwandter Variablen, nicht verändert.

# %%
# Hinweis: Wir gehen für das Beispiel davon aus, dass wir zum lesen
# der Märchen im Durschnitt 5.5 Minuten benötigen

lesezeit_minuten = 5.5 * märchen
print(lesezeit_minuten, "Minuten")

# %% [markdown]
# Erwarteter Output: `1100.0` Minuten
#
# Auf Basis der Anzahl der Märchen konnten wir uns also ausgeben lassen, wie viele Minuten wir gesamt lesen würden.
#
# ---
#
# ### Hinweis:
#
# Alles in einer Codezeile, was auf das Symbol "#" folgt, ist ein Kommentar, der von Python ignoriert wird. Kommentare ermöglichen es Programmierer:innen, Notizen oder Erklärungen für andere Programmierende oder aber für sich selbst zu hinterlassen, ohne, dass sie den Code beeinflussen.
#
# ---
#
# Ändern wir nun die Anzahl der *märchen*:

# %%
märchen = 240
print('Anzahl Märchen neu:', märchen, 'und Lesezeit in Minuten immer noch', lesezeit_minuten)

# %% [markdown]
# Wir sehen: Die Anzahl der Märchen ist nun nicht mehr 90, sondern 240.
#
# Denn: Wenn Variablen neu zugewiesen werden, wird der alte Wert 'vergessen'. Nur noch der aktuellste spielt dann eine Rolle.
# Da die Variable *lesezeit_minuten* sich nicht merkt, woher der Wert kommt, wird der Wert auch nicht automatisch aktualisiert, obwohl sich der Wert für die Variable *märchen* geändert hat.

# %% [markdown]
# # Übungen
#
# Wenn Sie Ihre Eingaben selbst überprüfen möchten, führen Sie folgenden Code einmalig aus (den müssen Sie jetzt hier nicht verstehen - keine Sorge). Dann kann eine Überprüfung Ihrer Antworten / Eingaben automatisch erfolgen.

# %%
import sys
sys.path.append('..')
from kurs_helpers import (
    pruefe_01_aufgabe_1a,
    pruefe_01_aufgabe_1b,
    pruefe_01_aufgabe_2,
    pruefe_01_aufgabe_3,
    erklaere_01_aufgabe_4,
)

# %% [markdown]
# **1.** Welche Werte haben die Variablen _masse_goldkugel_kg_ und _durchmesser_goldkugel_cm_ nach jeder der folgenden Anweisungen? Testen Sie Ihr Wissen und führen Sie jede Zelle nacheinander aus:

# %%
masse_goldkugel_kg = 3.47
durchmesser_goldkugel_cm = 7

# %% [markdown]
# Schreiben Sie hier den Code, um sich die oben gespeicherten Variablen ausgeben zu lassen:

# %%
# Hinweis: Hier sollen Sie mit der Print-Anweisung arbeiten.

# %%
# Überprüfung, ob obige Lösung richtig ist:

pruefe_01_aufgabe_1a()

# %%
masse_neu = masse_goldkugel_kg * 2.0
durchmesser_neu = durchmesser_goldkugel_cm + 5

# %% [markdown]
# Schreiben Sie hier Code, um sich die oben gespeicherten Variablen ausgeben zu lassen:

# %%
# Hinweis: Hier sollen Sie mit der Print-Anweisung arbeiten.

# %%
# Überprüfung, ob obige Lösung richtig ist:

pruefe_01_aufgabe_1b()

# %% [markdown]
# **2.** Welche Datentypen sind folgende Variablen?
#
# - x = 1.0
# - y = 5
# - z = "Froschkönig"
#
# Schreiben Sie hier Code, um sich den Datentyp ausgeben zu lassen:

# %%
# Hinweis: Definieren Sie zuerst x, y und z und nutzen Sie type(), um den Datentyp auszugeben

# %%
pruefe_01_aufgabe_2()

# %% [markdown]
# **3.** Was bewirken die letzten drei Zeilen dieses Programms in einfachen Worten?

# %%
x = 1.0
y = 3.0
swap = x
x = y
y = swap

# %% [markdown]
# Hier können Sie Ihre Antwort im Freitext formulieren und die Lösung danach anschauen:

# %% [markdown]
# ...

# %%
pruefe_01_aufgabe_3()

# %% [markdown]
# **4.** Vorhersage von Werten
#
# Wie lautet der Endwert der Variablen *position* im folgenden Programm? Versuchen Sie, den Wert vorherzusagen und überprüfen Sie dann Ihre Vorhersage.

# %%
initial = "left"
position = initial
initial = "right"

# %%
erklaere_01_aufgabe_4()

# %% [markdown]
# Nachdem wir nun anhand von Beispielen und Übungen die grundlegendsten Aufgaben von integer und float kennengelernt haben, wenden wir uns nun dem Datentyp String zu, da dieser für die Verarbeitung von Texten im Allgemeinen und Märchen im Speziellen natürlich sehr relevant ist.

# %% [markdown]
# ---
#
# **Geschafft!** Sie haben Kapitel 1 abgeschlossen.
#
# [← Zurück zur Übersicht](../00_Willkommen.ipynb) | [Weiter zu Kapitel 2: Strings und Booleans →](02_Strings_Booleans.ipynb)
