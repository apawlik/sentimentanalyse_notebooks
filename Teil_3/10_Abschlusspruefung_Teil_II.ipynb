# %% [markdown]
# # Abschlussprüfung Teil II
#
# In dieser Abschlussprüfung wenden Sie alles an, was Sie im gesamten Kurs gelernt haben — von der Textverarbeitung über die Sentimentanalyse bis zur Visualisierung.
#
# Ihre Aufgabe: Analysieren Sie die Stimmung von **10 Grimm'schen Märchen** und stellen Sie Ihre Ergebnisse grafisch dar.

# %%
# Hilfsfunktionen laden
import sys
sys.path.append('..')
import matplotlib.pyplot as plt
import numpy as np
from kurs_helpers import (
    lade_bereinigten_text,
    GERMAN_STOPWORDS,
    GRIMM_SENTIMENT_LEXIKON,
    berechne_sentiment_mit_negation,
    pruefe_10_abschlusspruefung,
)

# %% [markdown]
# ---
#
# ## Die 10 Märchen
#
# | Nr. | Märchen | Dateiname |
# |-----|---------|-----------|
# | 1 | Der Wolf und die sieben Geißlein | `WolfSiebenGeislein.txt` |
# | 2 | Rapunzel | `Rapunzel.txt` |
# | 3 | Hänsel und Gretel | `HaenselGrethel.txt` |
# | 4 | Das tapfere Schneiderlein | `TapfereSchneiderlein.txt` |
# | 5 | Aschenputtel | `Aschenbuttel.txt` |
# | 6 | Die Bremer Stadtmusikanten | `BremerStadtmusikanten.txt` |
# | 7 | Dornröschen | `Dornroeschen.txt` |
# | 8 | Tischchen deck dich | `TischchenDeckDich.txt` |
# | 9 | Schneewittchen | `Sneewittchen.txt` |
# | 10 | Rumpelstilzchen | `Rumpelstilzchen.txt` |
#
# ---
#
# ### Aufgabe 1: Sentiment Scores berechnen
#
# Laden Sie alle 10 Märchen, bereinigen Sie die Texte, entfernen Sie Stoppwörter und Zahlen, und berechnen Sie jeweils den Sentiment Score (mit Negationserkennung).
#
# Speichern Sie die Ergebnisse in `alle_namen` und `alle_scores`.

# %%
# Die 10 Märchen
maerchen_liste = {
    "Wolf & 7 Geißlein": "WolfSiebenGeislein.txt",
    "Rapunzel": "Rapunzel.txt",
    "Hänsel & Gretel": "HaenselGrethel.txt",
    "Tapferes Schneiderlein": "TapfereSchneiderlein.txt",
    "Aschenputtel": "Aschenbuttel.txt",
    "Bremer Stadtmusikanten": "BremerStadtmusikanten.txt",
    "Dornröschen": "Dornroeschen.txt",
    "Tischchen deck dich": "TischschenDeckDich.txt",
    "Schneewittchen": "Sneewittchen.txt",
    "Rumpelstilzchen": "Rumpelstilzchen.txt",
}

alle_namen = []
alle_scores = []

# Berechnen Sie hier die Scores für alle 10 Märchen

# %% [markdown]
# ### Aufgabe 2: Balkendiagramm
#
# Erstellen Sie ein Balkendiagramm, das die Sentiment Scores aller 10 Märchen vergleicht.

# %%
# Erstellen Sie hier das Balkendiagramm

# %% [markdown]
# ### Aufgabe 3: Spannungskurve
#
# Wählen Sie das Märchen mit dem **niedrigsten** (negativsten) Sentiment Score und erstellen Sie eine Spannungskurve. Nutzen Sie eine Abschnittsgröße von 50 Wörtern.
#
# Speichern Sie den Verlauf in `verlauf_pruefung` und den Märchennamen in `maerchen_pruefung`.

# %%
# Welches Märchen hat den niedrigsten Score?

# Text laden

# Stimmungsverlauf berechnen
verlauf_pruefung = []
maerchen_pruefung = "..."

# Grafik erstellen

# %% [markdown]
# ---
#
# ### Abschluss
#
# Bitte laden Sie ihr Jupyter-Notebook über Rechtsklick im Menü - Download - herunter und laden es in in Moodle als Abgabe zur Überprüfung hoch.

# %% [markdown]
# ---
#
# ## 🎉 Herzlichen Glückwunsch!
#
# Sie haben den gesamten Kurs abgeschlossen! Sie können jetzt:
#
# - Python-Grundlagen anwenden (Variablen, Strings, Listen, Schleifen, Bedingungen)
# - Textdateien einlesen und bereinigen
# - Eine lexikonbasierte Sentimentanalyse durchführen
# - Negationserkennung in Texten anwenden
# - Ergebnisse mit matplotlib visualisieren
# - Märchen miteinander vergleichen und Ergebnisse interpretieren
#
# Diese Fähigkeiten lassen sich auf viele andere Texte und Fragestellungen übertragen — nicht nur auf Märchen!
#
# ---
#
# ## Noch Lust auf einen Bonus?
#
# In unserem Bonus-Kapitel 11 erfahren Sie, wo die Grenzen liegen bzw. was das Thema Ironie für Auswirkungen haben kann...
#
# [← Zurück zur Übersicht](../00_Willkommen.ipynb) | [← Zurück zu Kapitel 9: Visualisierung](09_Visualisierung.ipynb) | [Weiter zu Kapitel 11: Bonus →](11_Bonuseinheit.ipynb)
